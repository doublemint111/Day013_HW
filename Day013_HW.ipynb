# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-meta-value').text)
    except:
        continue
# Out:
# [討論] 13年和14年馬刺熱火決賽
# 作者: kartg123456 (highflyball)
# [討論] Reddit今日熱門:Zion看起來像Toothless嗎
# 作者: pneumo (超☆冒險蓋)
# [花邊] 義大利死亡數創新高 馬刺射手：像電影
# 作者: lvntrs59 (瘋狂阿胖)
# [情報] NBA官方正重播Lillard 0.9秒絕殺火箭賽事
# 作者: love1500274 (CoWuCoWu)
# [新聞] 不滿川普疫情態度 勇士教頭推特對總統開
# 作者: kikiqq514 (翔楓寶寶)
# [花邊] 鄧肯自掏腰包 協助維京群島學生返家
# 作者: jjeffrey1015 (frey)
# [花邊]詹姆斯：訓練過後準備上樓洗澡,岳母叫住我
# 作者: PttGod (PttGod)
# [討論]  史上排名前五的射手投藍姿勢
# 作者: fan800509 (能不能給我一首歌的時間)
# Re: [討論]  史上排名前五的射手投藍姿勢
# 作者: justgetup (gonna fight)
# [花邊] Jamal Murray 上推特熱門
# 作者: gondou (共鬪)
# [情報] Jamal Murray IG帳號被盜
# 作者: Superman007 ()
# Re: [花邊] Jamal Murray 上推特熱門
# 作者: Bainite (黑羽毛 ┐(′д`)┌)
# Re: [討論]  史上排名前五的射手投藍姿勢
# 作者: godispower (親愛的 .別鬧了)
# [花邊] 為新球季做準備  勇士管理層：盼選即戰力
# 作者: thnlkj0665 (灰色地帶)
# [新聞] 跨足電競產業 卡珍斯簽約NRG戰隊
# 作者: s106667 (PHPJQJS)
# [討論] 誰感染誰的生涯就完了？
# 作者: andy880913 (相良醫生)
# Re: [討論]  史上排名前五的射手投藍姿勢
# 作者: SwissMiniGun (會移動的肥宅)
# [討論] 討論球員的模板的實質意義是什麼
# 作者: hhll5566 (忽溜56)
# [情報] Trae Young 推特: Masked Trae
# 作者: thnlkj0665 (灰色地帶)
# [公告] 板規v6.8
# ...

# %%
#印出文章第一頁的標題作者時間
for i in soup.find_all(class_="r-ent"):
    print('標題： ', i.find(class_='title').text.replace('\t', '').replace('\n', ''))
    print('作者： ', i.find(class_='author').text.replace('\t', '').replace('\n', ''))
    print('時間： ', i.find(class_='date').text.replace('\t', '').replace('\n', ''))
# Out:
# 標題：  [討論] 13年和14年馬刺熱火決賽
# 作者：  kartg123456
# 時間：   3/22
# 標題：  [討論] Reddit今日熱門:Zion看起來像Toothless嗎
# 作者：  pneumo
# 時間：   3/22
# 標題：  [花邊] 義大利死亡數創新高 馬刺射手：像電影
# 作者：  lvntrs59
# 時間：   3/22
# 標題：  [情報] NBA官方正重播Lillard 0.9秒絕殺火箭賽事
# 作者：  love1500274
# 時間：   3/22
# 標題：  [新聞] 不滿川普疫情態度 勇士教頭推特對總統開
# 作者：  kikiqq514
# 時間：   3/22
# 標題：  [花邊] 鄧肯自掏腰包 協助維京群島學生返家
# 作者：  jjeffrey1015
# 時間：   3/22
# 標題：  [花邊]詹姆斯：訓練過後準備上樓洗澡,岳母叫住我
# 作者：  PttGod
# 時間：   3/22
# 標題：  [討論]  史上排名前五的射手投藍姿勢
# 作者：  fan800509
# 時間：   3/22
# 標題：  Re: [討論]  史上排名前五的射手投藍姿勢
# 作者：  justgetup
# 時間：   3/22
# 標題：  [花邊] Jamal Murray 上推特熱門
# 作者：  gondou
# 時間：   3/22
# 標題：  [情報] Jamal Murray IG帳號被盜
# 作者：  Superman007
# 時間：   3/22
# 標題：  Re: [花邊] Jamal Murray 上推特熱門
# 作者：  Bainite
# 時間：   3/22
# 標題：  Re: [討論]  史上排名前五的射手投藍姿勢
# 作者：  godispower
# 時間：   3/22
# 標題：  [花邊] 為新球季做準備  勇士管理層：盼選即戰力
# 作者：  thnlkj0665
# 時間：   3/22
# 標題：  [新聞] 跨足電競產業 卡珍斯簽約NRG戰隊
# 作者：  s106667
# 時間：   3/22
# 標題：  [討論] 誰感染誰的生涯就完了？
# 作者：  andy880913
# 時間：   3/22
# ...

# %%
#第一題答案的第二中方法
#進入內頁抓
for d in soup.find_all(class_="title"):
    try:
        print('標題： ', d.text.replace('\t', '').replace('\n', ''))
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者： ' + r.find(class_='article-meta-value').text)
        print('時間： ' + r.find_all(class_='article-meta-value')[-1].text)
    except:
        continue
# Out:
# 標題：  [討論] 13年和14年馬刺熱火決賽
# 作者： kartg123456 (highflyball)
# 時間： Sun Mar 22 00:20:25 2020
# 標題：  [討論] Reddit今日熱門:Zion看起來像Toothless嗎
# 作者： pneumo (超☆冒險蓋)
# 時間： Sun Mar 22 00:22:46 2020
# 標題：  [花邊] 義大利死亡數創新高 馬刺射手：像電影
# 作者： lvntrs59 (瘋狂阿胖)
# 時間： Sun Mar 22 00:52:09 2020
# 標題：  [情報] NBA官方正重播Lillard 0.9秒絕殺火箭賽事
# 作者： love1500274 (CoWuCoWu)
# 時間： Sun Mar 22 04:56:02 2020
# 標題：  [新聞] 不滿川普疫情態度 勇士教頭推特對總統開
# 作者： kikiqq514 (翔楓寶寶)
# 時間： Sun Mar 22 07:54:44 2020
# 標題：  [花邊] 鄧肯自掏腰包 協助維京群島學生返家
# 作者： jjeffrey1015 (frey)
# 時間： Sun Mar 22 10:54:13 2020
# 標題：  [花邊]詹姆斯：訓練過後準備上樓洗澡,岳母叫住我
# 作者： PttGod (PttGod)
# 時間： Sun Mar 22 11:04:45 2020
# 標題：  [討論]  史上排名前五的射手投藍姿勢
# 作者： fan800509 (能不能給我一首歌的時間)
# 時間： Sun Mar 22 14:35:57 2020
# 標題：  Re: [討論]  史上排名前五的射手投藍姿勢
# 作者： justgetup (gonna fight)
# 時間： Sun Mar 22 15:52:42 2020
# 標題：  [花邊] Jamal Murray 上推特熱門
# 作者： gondou (共鬪)
# 時間： Sun Mar 22 16:18:48 2020
# 標題：  [情報] Jamal Murray IG帳號被盜
# 作者： Superman007 ()
# 時間： Sun Mar 22 16:51:27 2020
# ...

# %%
#印出最新文章的標題作者時間
#參考解答 因為原始的資料難以判斷「新/舊」，因此我們必須進入內頁抓取詳細的時間，最終存成 List of Dict 的形式再自行排序。

t = []

for i in soup.find_all(class_="title"):
    try:
        post = {}
        post['標題'] = i.text.replace('\t', '').replace('\n', '')
        
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+i.find('a')['href']).text, "html5lib")
        post['作者'] = r.find(class_='article-meta-value').text
        post['時間'] = r.find_all(class_='article-meta-value')[-1].text
        
        t.append(post)
    except:
        continue
        
t = sorted(t, key= lambda x: x['時間'])
# 補充：List of Dict 的排序方法
# https://stackoverflow.com/questions/72899/how-do-i-sort-a-list-of-dictionaries-by-a-value-of-the-dictionary
t[-1]
# Out:
# {'標題': '[情報] Trae Young 推特: Masked Trae',
#  '作者': 'thnlkj0665 (灰色地帶)',
#  '時間': 'Sun Mar 22 22:10:25 2020'}

# %%
url = 'https://www.ptt.cc/bbs/Lifeismoney/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

t2=[]
for i in soup.find_all(class_="title"):
    try:
        post = {}
        post['標題'] = i.text.replace('\t', '').replace('\n', '')
        
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+i.find('a')['href']).text, "html5lib")
        post['作者'] = r.find(class_='article-meta-value').text
        post['時間'] = r.find_all(class_='article-meta-value')[-1].text
        
        t.append(post)
    except:
        continue
        
t = sorted(t, key= lambda x: x['時間'])
t[-1]
# Out:
# {'標題': '[公告] 違規檢舉區', '作者': 'medama ( )', '時間': 'Thu Dec 19 22:54:37 2019'}

# %%
#答案補充1
# 改成 Gossiping 版，發生錯誤，因為八卦版會跳轉到一個「十八歲的同意驗證頁面」導致錯誤。
# 參考圖片下載時的解法，加上 cookies 繞過驗證（後面課程會再進行補充）


import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
r = requests.get(url, cookies={'over18': '1'})

soup = BeautifulSoup(r.text, "html5lib")

posts = []

for d in soup.find_all(class_="title"):
    try:
        post = {}
        post['標題'] = d.text.replace('\t', '').replace('\n', '')
        
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href'], cookies={'over18': '1'}).text, "html5lib")
        post['作者'] = r.find(class_='article-meta-value').text
        post['時間'] = r.find_all(class_='article-meta-value')[-1].text
        
        posts.append(post)
    except:
        continue
        
posts = sorted(posts, key= lambda x: x['時間'])
posts[-1]
# Out:
# {'標題': '[協尋] 埔里埔霧公路/七堵俊賢路/高雄博愛同盟路/交大/國一南下42',
#  '作者': 'arsonlolita (板主)',
#  '時間': 'Tue Mar 17 11:28:02 2020'}

# %%
#答案補充2
# 我們發現這個時間好像不是正確的，原因是我們前面存到的時間，其實不是正確的格式

# 改成 Gossiping 版，發生錯誤，因為八卦版會跳轉到一個「十八歲的同意驗證頁面」導致錯誤。
# 參考圖片下載時的解法，加上 cookies 繞過驗證（後面課程會再進行補充）


import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
r = requests.get(url, cookies={'over18': '1'})

soup = BeautifulSoup(r.text, "html5lib")

posts = []

for d in soup.find_all(class_="title"):
    try:
        post = {}
        post['標題'] = d.text.replace('\t', '').replace('\n', '')
        
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href'], cookies={'over18': '1'}).text, "html5lib")
        post['作者'] = r.find(class_='article-meta-value').text
        post['時間'] = r.find_all(class_='article-meta-value')[-1].text
        post['時間'] = datetime.strptime(post['時間'], "%a %b %d %H:%M:%S %Y")
        # 時間轉換：https://stackoverflow.com/questions/10256093/how-to-convert-ctime-to-datetime-in-python
        
        posts.append(post)
    except:
        continue
        
posts = sorted(posts, key= lambda x: x['時間'])
posts[-1]
